# %%
import json

# "label": ["People", "Artists, musicians, and composers", "Musicians and composers"]

ids, labels1, labels2 = [], [], []
with open('wikivitals-lvl5-04-2022.json', 'r', encoding='utf8') as f:
    for line in f:
        observation = json.loads(line)
        ids.append(observation['id'])
        labels1.append(observation['label'][0] + ' ->- ' + observation['label'][1])
        labels2.append(observation['label'][0] + ' ->- ' + observation['label'][1]+ ' ->- ' + observation['label'][2])
print(len(ids), len(labels1),len(labels2))
total_number_of_articles = len(ids)
ids2lsitindex = {ids[i]:i for i in range(len(ids))}
print(ids[:10])
print(labels1[:10])
print(labels2[:10])
print(f"Number of labels 1 and labels 2: {len(set(labels1)), len(set(labels2))}")
# Out:
# 48512 48512 48512
# ['1000', '100005', '100011', '100012', '10002', '100031', '100034', '100041', '1000530', '10005756']
# ['Arts ->- Arts', 'Biological and health sciences ->- Animals', 'Geography ->- Countries', 'People ->- Philosophers, historians, political and social scientists', 'People ->- Philosophers, historians, political and social scientists', 'People ->- Writers and journalists', 'Technology ->- Technology', 'People ->- Politicians and leaders', 'Geography ->- Countries', 'Mathematics ->- Mathematics']
# ['Arts ->- Arts ->- Fictional characters', 'Biological and health sciences ->- Animals ->- Birds', 'Geography ->- Countries ->- Regions and country subdivisions', 'People ->- Philosophers, historians, political and social scientists ->- Social scientists', 'People ->- Philosophers, historians, political and social scientists ->- Social scientists', 'People ->- Writers and journalists ->- Writers', 'Technology ->- Technology ->- General', 'People ->- Politicians and leaders ->- Ancient', 'Geography ->- Countries ->- Countries', 'Mathematics ->- Mathematics ->- Statistics and probability']
# Number of labels 1 and labels 2: (32, 251)

# %%
# Find level 2 classes with strictly less than 3 observations (ie. classes that cannot be split into 3 sets (train, validation, and test))
from collections import Counter
C = Counter(labels2)
labels_w_special_treatment = []
for label, num_obs in C.items():
    labels_w_special_treatment.append(label) if num_obs < 3 else None
print(labels_w_special_treatment)

# Filter these labels
ids_, labels1_, labels2_ = [], [], []
ids_with_special_treatment = []
for i in range(len(ids)):
    if not labels2[i] in labels_w_special_treatment:
        ids_.append(ids[i])
        labels1_.append(labels1[i])
        labels2_.append(labels2[i])
    else: 
        ids_with_special_treatment.append(ids[i])
print(len(ids_), len(labels1_),len(labels2_))
print(ids_with_special_treatment)
# Out:
# ['Physical sciences ->- Earth science ->- Earth science basics', 'People ->- Miscellaneous ->- Micronations']
# 48509 48509 48509
# ['20653168', '2890783', '31749258']

# %%
from sklearn.model_selection import train_test_split
import numpy as np


# Define the split sizes
train_size, validation_size, test_size = 0.81, 0.09, 0.10

relative_validation_size = validation_size / (validation_size + train_size)

X = np.array(ids_)
y1 = labels1_
y2 = labels2_

X_train, X_test, y_train, y_test = train_test_split(X, y2, test_size=test_size, random_state=42, shuffle=True, stratify=y2)
print(X_train.shape, X_test.shape, len(y_train), len(y_test))

X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=relative_validation_size, random_state=42, shuffle=True, stratify=y_train)
print(X_train.shape, X_val.shape, len(y_train), len(y_val))
# Out:
# (43658,) (4851,) 43658 4851
# (39292,) (4366,) 39292 4366

# %%
# Get the ids of the documents per split
ids_train = list(X_train)
ids_val = list(X_val)
ids_test = list(X_test)
# Reintegrate the labels we omitted (num. of observations < 3)
# All the missing articles are integrated into the train set beacause the total number
# of missing article is << than the total number of articles already in the train set 
# and it does not affect the overall split sizes 
ids_train = ids_train + ids_with_special_treatment

# Sanity check

# Display some statistics:
stats = [len(ids_train), len(ids_val), len(ids_test)]
stats = [f"{s/total_number_of_articles:.2f}" for s in stats]
print(f"Split sizes: {stats}")

# Check that all labels have at least one observation in the train set
indices_train = [ids2lsitindex[id] for id in ids_train]
labels1_train = [labels1[i] for i in indices_train]
labels2_train = [labels2[i] for i in indices_train]
print(f"Number of labels in the train set (labels 1 and labels 2): {len(set(labels1_train)), len(set(labels2_train))}")

print('\n')
indices_val = [ids2lsitindex[id] for id in ids_val]
indices_test = [ids2lsitindex[id] for id in ids_test]
labels1_val = [labels1[i] for i in indices_val]
labels2_val = [labels2[i] for i in indices_val]
labels1_test = [labels1[i] for i in indices_test]
labels2_test = [labels2[i] for i in indices_test]

C1_train, C1_val, C1_test = Counter(labels1_train), Counter(labels1_val), Counter(labels1_test)
C2_train, C2_val, C2_test = Counter(labels2_train), Counter(labels2_val), Counter(labels2_test)
all_labels1, all_labels2 = sorted(list(set(labels1))), sorted(list(set(labels2)))
C1 = {l:[0, 0, 0] for l in all_labels1}
C2 = {l:[0, 0, 0] for l in all_labels2}
for l in all_labels1:
    C1[l][0] = 0 if not l in C1_train.keys() else C1_train[l] / len(ids_train)
    C1[l][1] = 0 if not l in C1_val.keys() else C1_val[l] / len(ids_val)
    C1[l][2] = 0 if not l in C1_test.keys() else C1_test[l] / len(ids_test)
for l in all_labels2:
    C2[l][0] = 0 if not l in C2_train.keys() else C2_train[l]  / len(ids_train)
    C2[l][1] = 0 if not l in C2_val.keys() else C2_val[l]  / len(ids_val)
    C2[l][2] = 0 if not l in C2_test.keys() else C2_test[l]  / len(ids_test)

print('\n')
for l in all_labels1:
    print(f"{l} : {C1[l]}")

print('\n')
for l in all_labels2:
    print(f"{l} : {C2[l]}")
# Out:
# Split sizes: ['0.81', '0.09', '0.10']
# Number of labels in the train set (labels 1 and labels 2): (32, 251)
#
#
#
#
# Arts ->- Arts : [0.06827840692200025, 0.06802565277141548, 0.06802721088435375]
# Biological and health sciences ->- Animals : [0.04944649446494465, 0.04924415941365094, 0.049062049062049064]
# Biological and health sciences ->- Biology : [0.01827204478941341, 0.01809436555199267, 0.01834673263244692]
# Biological and health sciences ->- Health : [0.016312507952665735, 0.01626202473660101, 0.016285301999587713]
# Biological and health sciences ->- Plants : [0.012546125461254613, 0.012368300503893724, 0.012574726860441147]
# Everyday life ->- Everyday life : [0.024557831785214403, 0.024736601007787448, 0.02432488146773861]
# Everyday life ->- Sports, games and recreation : [0.02534673622598295, 0.025423728813559324, 0.025561739847454135]
# Geography ->- Cities : [0.04183738389108029, 0.04191479615208429, 0.04184704184704185]
# Geography ->- Countries : [0.028553251049751878, 0.028630325240494733, 0.02865388579674294]
# Geography ->- Physical : [0.03913983967425881, 0.03939532753092075, 0.039579468150896725]
# History ->- History : [0.06143275225855707, 0.061383417315620706, 0.061224489795918366]
# Mathematics ->- Mathematics : [0.02318361114645629, 0.0233623453962437, 0.02329416615130901]
# People ->- Artists, musicians, and composers : [0.047614200279933835, 0.04764086120018323, 0.047619047619047616]
# People ->- Entertainers, directors, producers, and screenwriters : [0.04827586206896552, 0.048327989005955106, 0.04823747680890538]
# People ->- Military personnel, revolutionaries, and activists : [0.0208677948848454, 0.020842876775080166, 0.020820449391877962]
# People ->- Miscellaneous : [0.02440514060313017, 0.024736601007787448, 0.024531024531024532]
# People ->- Philosophers, historians, political and social scientists : [0.02745896424481486, 0.0277141548327989, 0.027829313543599257]
# People ->- Politicians and leaders : [0.050540781269881666, 0.05061841502519469, 0.050505050505050504]
# People ->- Religious figures : [0.010306654790685838, 0.010306917086578103, 0.01030715316429602]
# People ->- Scientists, inventors, and mathematicians : [0.022801883191245705, 0.022904260192395786, 0.023088023088023088]
# People ->- Sports figures : [0.024914111210077618, 0.025194686211635363, 0.024943310657596373]
# People ->- Writers and journalists : [0.04366967807609111, 0.04374713696747595, 0.04390847247990105]
# Philosophy and religion ->- Philosophy and religion : [0.02901132459600458, 0.029088410444342648, 0.02906617192331478]
# Physical sciences ->- Astronomy : [0.018322941850108156, 0.017865322950068714, 0.018140589569160998]
# Physical sciences ->- Basics and measurement : [0.0074564193917801246, 0.007329363261566651, 0.007215007215007215]
# Physical sciences ->- Chemistry : [0.024914111210077618, 0.024736601007787448, 0.024737167594310452]
# Physical sciences ->- Earth science : [0.01750858887899224, 0.017407237746220796, 0.017522160379303237]
# Physical sciences ->- Physics : [0.020409721338592698, 0.02038479157123225, 0.019995877138734283]
# Society and social sciences ->- Culture : [0.0427535309835857, 0.04306000916170408, 0.04267161410018553]
# Society and social sciences ->- Politic and economic : [0.03758747932306909, 0.03779202931745305, 0.03772418058132344]
# Society and social sciences ->- Social studies : [0.0073291767400432625, 0.007100320659642693, 0.0074211502782931356]
# Technology ->- Technology : [0.06494464944649446, 0.06436097114063216, 0.06493506493506493]
#
#
# Arts ->- Arts ->- Architecture : [0.005140603130169233, 0.005038937242327073, 0.00515357658214801]
# Arts ->- Arts ->- Cultural venues : [0.0026975442168214784, 0.002748511223087494, 0.0026798598227169654]
# Arts ->- Arts ->- Fictional characters : [0.0027738898078635958, 0.002748511223087494, 0.0026798598227169654]
# Arts ->- Arts ->- General : [0.0001272426517368622, 0, 0]
# Arts ->- Arts ->- Literature : [0.020384272808245323, 0.02038479157123225, 0.02040816326530612]
# Arts ->- Arts ->- Modern visual arts : [0.006209441404758875, 0.006184150251946862, 0.006184291898577613]
# Arts ->- Arts ->- Music : [0.01656699325613946, 0.016491067338524967, 0.016491445062873634]
# Arts ->- Arts ->- Performing arts : [0.00407176485557959, 0.004122766834631242, 0.0041228612657184084]
# Arts ->- Arts ->- Visual arts : [0.010306654790685838, 0.010306917086578103, 0.01030715316429602]
# Biological and health sciences ->- Animals ->- Agnatha : [0.00035627942486321414, 0.00022904260192395785, 0.00041228612657184083]
# Biological and health sciences ->- Animals ->- Amphibians : [0.0011197353352843872, 0.0011452130096197893, 0.0012368583797155227]
# Biological and health sciences ->- Animals ->- Animal breeds and hybrids : [0.0030792721720320653, 0.002977553825011452, 0.0030921459492888066]
# Biological and health sciences ->- Animals ->- Arachnids : [0.0010688382745896424, 0.0011452130096197893, 0.0010307153164296021]
# Biological and health sciences ->- Animals ->- Arthropoda, others : [0.0007380073800738007, 0.0006871278057718735, 0.0006184291898577613]
# Biological and health sciences ->- Animals ->- Birds : [0.007889044407685456, 0.007787448465414567, 0.007833436404864976]
# Biological and health sciences ->- Animals ->- Cnidarians : [0.0004580735462527039, 0.0004580852038479157, 0.00041228612657184083]
# Biological and health sciences ->- Animals ->- Crustaceans : [0.001730500063621326, 0.0018323408153916628, 0.0016491445062873633]
# Biological and health sciences ->- Animals ->- Echinoderms : [0.0003308308945158417, 0.00022904260192395785, 0.00020614306328592042]
# Biological and health sciences ->- Animals ->- Fishes : [0.006158544344064131, 0.006184150251946862, 0.006184291898577613]
# Biological and health sciences ->- Animals ->- General classifications : [0.0002799338338210968, 0.00022904260192395785, 0.00020614306328592042]
# Biological and health sciences ->- Animals ->- Individual animals : [0.0019595368367476777, 0.0018323408153916628, 0.0018552875695732839]
# Biological and health sciences ->- Animals ->- Insects : [0.0040208677948848455, 0.004122766834631242, 0.0041228612657184084]
# Biological and health sciences ->- Animals ->- Invertebrata, others : [0.0010688382745896424, 0.0011452130096197893, 0.0010307153164296021]
# Biological and health sciences ->- Animals ->- Mammals : [0.011095559231454383, 0.011223087494273936, 0.011131725417439703]
# Biological and health sciences ->- Animals ->- Mollusks : [0.0014251176994528566, 0.001374255611543747, 0.001443001443001443]
# Biological and health sciences ->- Animals ->- Porifera : [0.0001272426517368622, 0, 0]
# Biological and health sciences ->- Animals ->- Proto-mammals : [0.00035627942486321414, 0.0004580852038479157, 0.00041228612657184083]
# Biological and health sciences ->- Animals ->- Reptiles : [0.006107647283369385, 0.006184150251946862, 0.006184291898577613]
# Biological and health sciences ->- Animals ->- Reptiliomorphs : [7.634559104211732e-05, 0, 0]
# Biological and health sciences ->- Biology ->- Anatomy and morphology : [0.005496882555032447, 0.005497022446174988, 0.0055658627087198514]
# Biological and health sciences ->- Biology ->- Biochemistry and molecular biology : [0.003308308945158417, 0.00320659642693541, 0.0032982890125747267]
# Biological and health sciences ->- Biology ->- Biological processes and physiology : [0.0022903677312635195, 0.0022904260192395786, 0.0022675736961451248]
# Biological and health sciences ->- Biology ->- Biology basics : [0.0009670441532001527, 0.0009161704076958314, 0.0010307153164296021]
# Biological and health sciences ->- Biology ->- Botany : [0.00017813971243160707, 0.00022904260192395785, 0.00020614306328592042]
# Biological and health sciences ->- Biology ->- Cell biology : [0.0016032574118844637, 0.001603298213467705, 0.0016491445062873633]
# Biological and health sciences ->- Biology ->- Ecology : [0.0008143529711159181, 0.0006871278057718735, 0.0008245722531436817]
# Biological and health sciences ->- Biology ->- Evolutionary biology : [0.001908639776052933, 0.0018323408153916628, 0.0018552875695732839]
# Biological and health sciences ->- Biology ->- Genetics : [0.0008398015014632905, 0.0009161704076958314, 0.0008245722531436817]
# Biological and health sciences ->- Biology ->- Zoology : [0.000865250031810663, 0.0009161704076958314, 0.0008245722531436817]
# Biological and health sciences ->- Health ->- Drugs and medication : [0.002493955974042499, 0.0025194686211635364, 0.0024737167594310453]
# Biological and health sciences ->- Health ->- Health and fitness : [0.0019340883064003053, 0.0018323408153916628, 0.0018552875695732839]
# Biological and health sciences ->- Health ->- Medicine : [0.004097213385926963, 0.004122766834631242, 0.0041228612657184084]
# Biological and health sciences ->- Health ->- Morbidity : [0.007787250286295966, 0.007787448465414567, 0.007833436404864976]
# Biological and health sciences ->- Plants ->- Fungi : [0.0007380073800738007, 0.0006871278057718735, 0.0008245722531436817]
# Biological and health sciences ->- Plants ->- Other organisms : [0.0014251176994528566, 0.001374255611543747, 0.001443001443001443]
# Biological and health sciences ->- Plants ->- Plants : [0.010383000381727955, 0.010306917086578103, 0.01030715316429602]
# Everyday life ->- Everyday life ->- Clothing and fashion : [0.003969970734190101, 0.0038937242327072834, 0.003916718202432488]
# Everyday life ->- Everyday life ->- Cooking, food and drink : [0.013487721084107392, 0.013513513513513514, 0.013399299113584827]
# Everyday life ->- Everyday life ->- Family and kinship : [0.0019849853670950504, 0.002061383417315621, 0.0020614306328592042]
# Everyday life ->- Everyday life ->- General : [7.634559104211732e-05, 0, 0]
# Everyday life ->- Everyday life ->- Home living : [0.00035627942486321414, 0.0004580852038479157, 0.00041228612657184083]
# Everyday life ->- Everyday life ->- Household items : [0.0015269118208423463, 0.001603298213467705, 0.001443001443001443]
# Everyday life ->- Everyday life ->- Sexuality and gender : [0.002850235398905713, 0.002977553825011452, 0.002886002886002886]
# Everyday life ->- Everyday life ->- Stages of life : [0.0003053823641684693, 0.00022904260192395785, 0.00020614306328592042]
# Everyday life ->- Sports, games and recreation ->- Entertainment : [0.010662934215549051, 0.01076500229042602, 0.010719439290867862]
# Everyday life ->- Sports, games and recreation ->- Sports : [0.011248250413538618, 0.011223087494273936, 0.011337868480725623]
# Everyday life ->- Sports, games and recreation ->- Sports organizations : [0.003435551596895279, 0.003435639028859368, 0.0035044320758606472]
# Geography ->- Cities ->- Africa : [0.0046570810535691565, 0.004580852038479157, 0.00474129045557617]
# Geography ->- Cities ->- Americas : [0.007965389998727573, 0.008016491067338524, 0.008039579468150896]
# Geography ->- Cities ->- Asia : [0.017992110955592316, 0.01809436555199267, 0.017934446505875078]
# Geography ->- Cities ->- Europe and Russia : [0.009059676803664589, 0.009161704076958314, 0.009070294784580499]
# Geography ->- Cities ->- Non-city settlements : [0.00035627942486321414, 0.00022904260192395785, 0.00041228612657184083]
# Geography ->- Cities ->- Oceania : [0.0008906985621580354, 0.0009161704076958314, 0.0008245722531436817]
# Geography ->- Cities ->- Urban studies and planning : [0.0009161470925054078, 0.0009161704076958314, 0.0008245722531436817]
# Geography ->- Countries ->- Countries : [0.004555286932179666, 0.004580852038479157, 0.0045351473922902496]
# Geography ->- Countries ->- General : [0.00038172795521058657, 0.0004580852038479157, 0.00041228612657184083]
# Geography ->- Countries ->- Regions and country subdivisions : [0.023616236162361623, 0.023591387998167658, 0.02370645227788085]
# Geography ->- Physical ->- Basics : [0.0016032574118844637, 0.001603298213467705, 0.0016491445062873633]
# Geography ->- Physical ->- Bodies of water : [0.010891970988675405, 0.010994044892349977, 0.010925582354153782]
# Geography ->- Physical ->- Geography by country : [0.0010688382745896424, 0.0011452130096197893, 0.0010307153164296021]
# Geography ->- Physical ->- Islands : [0.010103066547906858, 0.010077874484654145, 0.010101010101010102]
# Geography ->- Physical ->- Isthmuses : [0.00020358824277897953, 0.00022904260192395785, 0.00020614306328592042]
# Geography ->- Physical ->- Land relief : [0.0046570810535691565, 0.004580852038479157, 0.00474129045557617]
# Geography ->- Physical ->- Mountain peaks : [0.0026211986257793614, 0.002748511223087494, 0.0026798598227169654]
# Geography ->- Physical ->- Other hydrological features : [0.0022394706705687745, 0.0022904260192395786, 0.0022675736961451248]
# Geography ->- Physical ->- Other terrestrial features : [0.0018322941850108156, 0.0018323408153916628, 0.0018552875695732839]
# Geography ->- Physical ->- Parks, preserves, and World Heritage Sites : [0.0021631250795266575, 0.002061383417315621, 0.0022675736961451248]
# Geography ->- Physical ->- Peninsulas and capes : [0.0017559485939686982, 0.0018323408153916628, 0.0018552875695732839]
# History ->- History ->- 19th century : [0.0049115663570428805, 0.004809894640403115, 0.004947433518862091]
# History ->- History ->- 20th century : [0.011604529838401833, 0.01168117269812185, 0.011544011544011544]
# History ->- History ->- 21st century : [0.0035373457182847692, 0.0036646816307833257, 0.0035044320758606472]
# History ->- History ->- Ancient history : [0.0061839928744115025, 0.006184150251946862, 0.006184291898577613]
# History ->- History ->- Basics : [0.0007380073800738007, 0.0006871278057718735, 0.0008245722531436817]
# History ->- History ->- Early modern history : [0.005573228146074564, 0.005497022446174988, 0.0055658627087198514]
# History ->- History ->- Historical cities, towns and archaeological sites : [0.0021631250795266575, 0.002061383417315621, 0.0020614306328592042]
# History ->- History ->- History by city : [0.0008143529711159181, 0.0006871278057718735, 0.0008245722531436817]
# History ->- History ->- History by continent and region : [0.000865250031810663, 0.0009161704076958314, 0.0008245722531436817]
# History ->- History ->- History by country and subdivision : [0.00865250031810663, 0.008703618873110398, 0.008658008658008658]
# History ->- History ->- History by ethnicity : [0.00015269118208423465, 0.00022904260192395785, 0.00020614306328592042]
# History ->- History ->- History by topic : [0.006667514951011579, 0.006642235455794778, 0.006596578025149453]
# History ->- History ->- Post-classical history : [0.009085125334011962, 0.009161704076958314, 0.009070294784580499]
# History ->- History ->- Prehistory : [0.00048352207660007634, 0.0004580852038479157, 0.00041228612657184083]
# Mathematics ->- Mathematics ->- Algebra : [0.0015269118208423463, 0.001603298213467705, 0.001443001443001443]
# Mathematics ->- Mathematics ->- Applied mathematics : [0.0007380073800738007, 0.0006871278057718735, 0.0008245722531436817]
# Mathematics ->- Mathematics ->- Basics : [0.002366713322305637, 0.0022904260192395786, 0.0022675736961451248]
# Mathematics ->- Mathematics ->- Calculus and analysis : [0.003639139839674259, 0.0036646816307833257, 0.0037105751391465678]
# Mathematics ->- Mathematics ->- Discrete mathematics : [0.0028756839292530855, 0.002977553825011452, 0.002886002886002886]
# Mathematics ->- Mathematics ->- Foundations : [0.003308308945158417, 0.00320659642693541, 0.0032982890125747267]
# Mathematics ->- Mathematics ->- Functions : [0.001806845654663443, 0.0018323408153916628, 0.0018552875695732839]
# Mathematics ->- Mathematics ->- Geometry : [0.002850235398905713, 0.002977553825011452, 0.002886002886002886]
# Mathematics ->- Mathematics ->- Number theory : [0.00104338974424227, 0.0009161704076958314, 0.0010307153164296021]
# Mathematics ->- Mathematics ->- Statistics and probability : [0.001730500063621326, 0.0018323408153916628, 0.0018552875695732839]
# Mathematics ->- Mathematics ->- Theoretical computer science : [0.0012978750477159943, 0.001374255611543747, 0.0012368583797155227]
# People ->- Artists, musicians, and composers ->- Musicians and composers : [0.03099630996309963, 0.03092075125973431, 0.030921459492888066]
# People ->- Artists, musicians, and composers ->- Visual artists : [0.016617890316834204, 0.016720109940448924, 0.016697588126159554]
# People ->- Entertainers, directors, producers, and screenwriters ->- Comedians : [0.004504389871484922, 0.004580852038479157, 0.0045351473922902496]
# People ->- Entertainers, directors, producers, and screenwriters ->- Dancers and choreographers : [0.004122661916274335, 0.004122766834631242, 0.0041228612657184084]
# People ->- Entertainers, directors, producers, and screenwriters ->- Entertainers : [0.029367604020867796, 0.029317453046266605, 0.0292723149866007]
# People ->- Entertainers, directors, producers, and screenwriters ->- Other entertainment and fields : [0.006133095813716758, 0.006184150251946862, 0.006184291898577613]
# People ->- Entertainers, directors, producers, and screenwriters ->- Television hosts and personalities : [0.0041481104466217075, 0.004122766834631242, 0.0041228612657184084]
# People ->- Military personnel, revolutionaries, and activists ->- Military leaders, personnel, and theorists : [0.009695890062348899, 0.00961978928080623, 0.00968872397443826]
# People ->- Military personnel, revolutionaries, and activists ->- Rebels, revolutionaries and activists : [0.011171904822496501, 0.011223087494273936, 0.011131725417439703]
# People ->- Miscellaneous ->- Body modification : [0.00020358824277897953, 0.00022904260192395785, 0.00020614306328592042]
# People ->- Miscellaneous ->- Businesspeople : [0.007609110573864359, 0.0075584058634906096, 0.007627293341579056]
# People ->- Miscellaneous ->- Case studies : [0.0005344191372948212, 0.0004580852038479157, 0.00041228612657184083]
# People ->- Miscellaneous ->- Chefs, bartenders and winemakers : [0.0008143529711159181, 0.0009161704076958314, 0.0008245722531436817]
# People ->- Miscellaneous ->- Cosmetics people : [0.00020358824277897953, 0.00022904260192395785, 0.00020614306328592042]
# People ->- Miscellaneous ->- Crime : [0.005140603130169233, 0.005267979844251031, 0.00515357658214801]
# People ->- Miscellaneous ->- Explorers : [0.005649573737116682, 0.0057260650480989465, 0.005772005772005772]
# People ->- Miscellaneous ->- Fandom, conventions and festivals : [0.00020358824277897953, 0.00022904260192395785, 0.00020614306328592042]
# People ->- Miscellaneous ->- Health and fitness : [0.0001272426517368622, 0, 0.00020614306328592042]
# People ->- Miscellaneous ->- Hobbyists : [0.00020358824277897953, 0.00022904260192395785, 0.00020614306328592042]
# People ->- Miscellaneous ->- Law enforcement and fire service : [0.0012469779870212495, 0.0011452130096197893, 0.0012368583797155227]
# People ->- Miscellaneous ->- Micronations : [5.089706069474488e-05, 0, 0]
# People ->- Miscellaneous ->- Other : [0.00022903677312635195, 0.00022904260192395785, 0.00020614306328592042]
# People ->- Miscellaneous ->- Pseudoscientists : [0.0008143529711159181, 0.0009161704076958314, 0.0008245722531436817]
# People ->- Miscellaneous ->- Sex work : [0.00040717648555795905, 0.0004580852038479157, 0.00041228612657184083]
# People ->- Miscellaneous ->- Socialites : [0.0008143529711159181, 0.0009161704076958314, 0.0008245722531436817]
# People ->- Miscellaneous ->- Tradespeople : [0.00015269118208423465, 0.00022904260192395785, 0.00020614306328592042]
# People ->- Philosophers, historians, political and social scientists ->- Historians : [0.003588242778979514, 0.0036646816307833257, 0.0037105751391465678]
# People ->- Philosophers, historians, political and social scientists ->- Philosophers : [0.0060567502226746405, 0.006184150251946862, 0.006184291898577613]
# People ->- Philosophers, historians, political and social scientists ->- Social scientists : [0.017813971243160708, 0.017865322950068714, 0.017934446505875078]
# People ->- Politicians and leaders ->- Ancient : [0.005776816388853544, 0.0057260650480989465, 0.005772005772005772]
# People ->- Politicians and leaders ->- Early modern period [about 1400-1814] : [0.007889044407685456, 0.008016491067338524, 0.007833436404864976]
# People ->- Politicians and leaders ->- Modern [about 1815-1945] : [0.010332103321033211, 0.010306917086578103, 0.01030715316429602]
# People ->- Politicians and leaders ->- Post-1945 : [0.01918819188191882, 0.01923957856161246, 0.0191713048855906]
# People ->- Politicians and leaders ->- Post-classical : [0.007354625270390635, 0.007329363261566651, 0.0074211502782931356]
# People ->- Religious figures ->- Buddhism : [0.0012469779870212495, 0.0011452130096197893, 0.0012368583797155227]
# People ->- Religious figures ->- Christianity : [0.004962463417737626, 0.005038937242327073, 0.004947433518862091]
# People ->- Religious figures ->- Hinduism : [0.0007634559104211731, 0.0006871278057718735, 0.0008245722531436817]
# People ->- Religious figures ->- Islam : [0.0018577427153581882, 0.0018323408153916628, 0.0018552875695732839]
# People ->- Religious figures ->- Judaism : [0.0005853161979895662, 0.0006871278057718735, 0.0006184291898577613]
# People ->- Religious figures ->- Others : [0.0008906985621580354, 0.0009161704076958314, 0.0008245722531436817]
# People ->- Scientists, inventors, and mathematicians ->- Chemistry : [0.0016287059422318362, 0.001603298213467705, 0.0016491445062873633]
# People ->- Scientists, inventors, and mathematicians ->- Computer scientists and programmers : [0.00104338974424227, 0.0011452130096197893, 0.0010307153164296021]
# People ->- Scientists, inventors, and mathematicians ->- Inventors and engineers : [0.0037918310217584933, 0.0038937242327072834, 0.003916718202432488]
# People ->- Scientists, inventors, and mathematicians ->- Life sciences : [0.004555286932179666, 0.004580852038479157, 0.0045351473922902496]
# People ->- Scientists, inventors, and mathematicians ->- Mathematicians : [0.0026466471561267337, 0.002748511223087494, 0.0026798598227169654]
# People ->- Scientists, inventors, and mathematicians ->- Physical geography : [0.0009670441532001527, 0.0009161704076958314, 0.0010307153164296021]
# People ->- Scientists, inventors, and mathematicians ->- Physics and astronomy : [0.006972897315180048, 0.006871278057718736, 0.0070088641517212944]
# People ->- Scientists, inventors, and mathematicians ->- Pre-modern figures : [0.0011960809263265046, 0.0011452130096197893, 0.0012368583797155227]
# People ->- Sports figures ->- American football : [0.0008143529711159181, 0.0009161704076958314, 0.0008245722531436817]
# People ->- Sports figures ->- Ancient sports : [0.0001272426517368622, 0, 0]
# People ->- Sports figures ->- Association football : [0.0022649192009161472, 0.0022904260192395786, 0.0022675736961451248]
# People ->- Sports figures ->- Athletics : [0.0018831912457055605, 0.0018323408153916628, 0.0018552875695732839]
# People ->- Sports figures ->- Auto racing : [0.0008143529711159181, 0.0009161704076958314, 0.0008245722531436817]
# People ->- Sports figures ->- Baseball : [0.0011451838656317598, 0.0011452130096197893, 0.0012368583797155227]
# People ->- Sports figures ->- Basketball : [0.0012469779870212495, 0.0011452130096197893, 0.0012368583797155227]
# People ->- Sports figures ->- Cricket : [0.0012469779870212495, 0.0011452130096197893, 0.0012368583797155227]
# People ->- Sports figures ->- Cycling : [0.00040717648555795905, 0.0004580852038479157, 0.00041228612657184083]
# People ->- Sports figures ->- Figure skating : [0.0006107647283369386, 0.0006871278057718735, 0.0006184291898577613]
# People ->- Sports figures ->- Golf : [0.0007380073800738007, 0.0006871278057718735, 0.0006184291898577613]
# People ->- Sports figures ->- Gymnastics : [0.0005344191372948212, 0.0004580852038479157, 0.00041228612657184083]
# People ->- Sports figures ->- Ice hockey : [0.0009161470925054078, 0.0009161704076958314, 0.0010307153164296021]
# People ->- Sports figures ->- Martial arts : [0.001730500063621326, 0.0018323408153916628, 0.0018552875695732839]
# People ->- Sports figures ->- Other individual sports : [0.0031047207023794376, 0.00320659642693541, 0.0030921459492888066]
# People ->- Sports figures ->- Other team sports : [0.0012215294566738772, 0.0011452130096197893, 0.0012368583797155227]
# People ->- Sports figures ->- Rugby : [0.0006107647283369386, 0.0006871278057718735, 0.0006184291898577613]
# People ->- Sports figures ->- Sports business-people, coaches, and referees : [0.00313016923272681, 0.00320659642693541, 0.0030921459492888066]
# People ->- Sports figures ->- Swimming : [0.00040717648555795905, 0.0004580852038479157, 0.00041228612657184083]
# People ->- Sports figures ->- Tabletop games : [0.0009161470925054078, 0.0009161704076958314, 0.0010307153164296021]
# People ->- Sports figures ->- Tennis : [0.00104338974424227, 0.0011452130096197893, 0.0010307153164296021]
# People ->- Writers and journalists ->- Journalists : [0.008118081180811807, 0.008245533669262483, 0.008245722531436817]
# People ->- Writers and journalists ->- Writers : [0.0355515968952793, 0.03550160329821347, 0.03566274994846423]
# Philosophy and religion ->- Philosophy and religion ->- Abrahamic religions : [0.008474360605675023, 0.00847457627118644, 0.008451865594722737]
# Philosophy and religion ->- Philosophy and religion ->- Eastern religions : [0.003995419264537473, 0.004122766834631242, 0.003916718202432488]
# Philosophy and religion ->- Philosophy and religion ->- Mythology : [0.007507316452474869, 0.0075584058634906096, 0.007627293341579056]
# Philosophy and religion ->- Philosophy and religion ->- Other religions : [0.0014760147601476014, 0.001374255611543747, 0.001443001443001443]
# Philosophy and religion ->- Philosophy and religion ->- Philosophy : [0.004046316325232218, 0.004122766834631242, 0.0041228612657184084]
# Philosophy and religion ->- Philosophy and religion ->- Religion and spirituality : [0.0035118971879373965, 0.003435639028859368, 0.0035044320758606472]
# Physical sciences ->- Astronomy ->- Astronomical objects : [0.006234889935106248, 0.006184150251946862, 0.006184291898577613]
# Physical sciences ->- Astronomy ->- Astronomy basics : [0.0007380073800738007, 0.0006871278057718735, 0.0006184291898577613]
# Physical sciences ->- Astronomy ->- Celestial mechanics : [0.001501463290494974, 0.001374255611543747, 0.001443001443001443]
# Physical sciences ->- Astronomy ->- Celestial sphere : [0.0025194045043898713, 0.0025194686211635364, 0.0024737167594310453]
# Physical sciences ->- Astronomy ->- Galactic and extragalactic astronomy : [0.0018322941850108156, 0.0018323408153916628, 0.0018552875695732839]
# Physical sciences ->- Astronomy ->- Observational astronomy : [0.0010179412138948975, 0.0009161704076958314, 0.0010307153164296021]
# Physical sciences ->- Astronomy ->- Physical cosmology : [0.00104338974424227, 0.0011452130096197893, 0.0010307153164296021]
# Physical sciences ->- Astronomy ->- Planetary science : [0.00104338974424227, 0.0009161704076958314, 0.0010307153164296021]
# Physical sciences ->- Astronomy ->- Stellar astronomy : [0.0023921618526530092, 0.0022904260192395786, 0.0024737167594310453]
# Physical sciences ->- Basics and measurement ->- Measurement : [0.006234889935106248, 0.006184150251946862, 0.006184291898577613]
# Physical sciences ->- Basics and measurement ->- Science basics : [0.0008906985621580354, 0.0009161704076958314, 0.0008245722531436817]
# Physical sciences ->- Basics and measurement ->- Science in countries : [0.0003308308945158417, 0.00022904260192395785, 0.00020614306328592042]
# Physical sciences ->- Chemistry ->- Acids and bases : [0.0011197353352843872, 0.0011452130096197893, 0.0010307153164296021]
# Physical sciences ->- Chemistry ->- Alloys and ceramic compounds : [0.0008143529711159181, 0.0006871278057718735, 0.0008245722531436817]
# Physical sciences ->- Chemistry ->- Analysis : [0.0008143529711159181, 0.0009161704076958314, 0.0008245722531436817]
# Physical sciences ->- Chemistry ->- Basics : [0.0027993383382109685, 0.002748511223087494, 0.002886002886002886]
# Physical sciences ->- Chemistry ->- Chemical elements : [0.004224456037663825, 0.004122766834631242, 0.0041228612657184084]
# Physical sciences ->- Chemistry ->- Chemical engineering : [0.0002544853034737244, 0.00022904260192395785, 0.00020614306328592042]
# Physical sciences ->- Chemistry ->- Molecular compounds : [0.001272426517368622, 0.0011452130096197893, 0.0012368583797155227]
# Physical sciences ->- Chemistry ->- Organic compounds : [0.003995419264537473, 0.004122766834631242, 0.003916718202432488]
# Physical sciences ->- Chemistry ->- Reactions and synthesis : [0.001679603002926581, 0.001603298213467705, 0.0016491445062873633]
# Physical sciences ->- Chemistry ->- Salts and ions : [0.0045298384018322944, 0.004580852038479157, 0.0045351473922902496]
# Physical sciences ->- Chemistry ->- Separation processes : [0.0011451838656317598, 0.0011452130096197893, 0.0012368583797155227]
# Physical sciences ->- Chemistry ->- Theory : [0.0022649192009161472, 0.0022904260192395786, 0.0022675736961451248]
# Physical sciences ->- Earth science ->- Air : [0.0030283751113373203, 0.002977553825011452, 0.0030921459492888066]
# Physical sciences ->- Earth science ->- Biological materials : [7.634559104211732e-05, 0, 0]
# Physical sciences ->- Earth science ->- Earth : [0.012953301946812571, 0.013055428309665598, 0.012987012987012988]
# Physical sciences ->- Earth science ->- Earth science basics : [2.544853034737244e-05, 0, 0]
# Physical sciences ->- Earth science ->- Water : [0.0014251176994528566, 0.001374255611543747, 0.001443001443001443]
# Physical sciences ->- Physics ->- Atomic, molecular and optical physics : [0.0019340883064003053, 0.0018323408153916628, 0.0018552875695732839]
# Physical sciences ->- Physics ->- Color : [0.001094286804937015, 0.0011452130096197893, 0.0010307153164296021]
# Physical sciences ->- Physics ->- Condensed matter physics : [0.0016032574118844637, 0.001603298213467705, 0.0016491445062873633]
# Physical sciences ->- Physics ->- Electromagnetism : [0.002493955974042499, 0.0025194686211635364, 0.0024737167594310453]
# Physical sciences ->- Physics ->- Mechanics : [0.005624125206769309, 0.0057260650480989465, 0.0055658627087198514]
# Physical sciences ->- Physics ->- Nuclear physics : [0.0005344191372948212, 0.0004580852038479157, 0.00041228612657184083]
# Physical sciences ->- Physics ->- Particle physics : [0.0022903677312635195, 0.0022904260192395786, 0.0022675736961451248]
# Physical sciences ->- Physics ->- Physics basics : [0.001272426517368622, 0.001374255611543747, 0.0012368583797155227]
# Physical sciences ->- Physics ->- Theory of relativity : [0.0007380073800738007, 0.0006871278057718735, 0.0006184291898577613]
# Physical sciences ->- Physics ->- Thermodynamics : [0.0018322941850108156, 0.0018323408153916628, 0.0018552875695732839]
# Physical sciences ->- Physics ->- Waves : [0.0009924926835475252, 0.0009161704076958314, 0.0010307153164296021]
# Society and social sciences ->- Culture ->- Communication : [0.00104338974424227, 0.0011452130096197893, 0.0010307153164296021]
# Society and social sciences ->- Culture ->- Culture : [0.002722992747168851, 0.002748511223087494, 0.0026798598227169654]
# Society and social sciences ->- Culture ->- Education : [0.007278279679348518, 0.007329363261566651, 0.007215007215007215]
# Society and social sciences ->- Culture ->- Ethnology and Anthropology : [0.0024685074436951266, 0.0025194686211635364, 0.0024737167594310453]
# Society and social sciences ->- Culture ->- Journalism and mass media : [0.01699961827204479, 0.01694915254237288, 0.017109874252731395]
# Society and social sciences ->- Culture ->- Language : [0.012240743097086143, 0.012368300503893724, 0.012162440733869306]
# Society and social sciences ->- Politic and economic ->- Business and economics : [0.013767654917928489, 0.013742556115437472, 0.013811585240156668]
# Society and social sciences ->- Politic and economic ->- Law : [0.01168087542944395, 0.01168117269812185, 0.011750154607297465]
# Society and social sciences ->- Politic and economic ->- Organizations : [0.005140603130169233, 0.005267979844251031, 0.00515357658214801]
# Society and social sciences ->- Politic and economic ->- Politics and government : [0.004733426644611274, 0.004809894640403115, 0.00474129045557617]
# Society and social sciences ->- Politic and economic ->- War and military : [0.0022649192009161472, 0.0022904260192395786, 0.0022675736961451248]
# Society and social sciences ->- Social studies ->- Basics : [0.00035627942486321414, 0.00022904260192395785, 0.00041228612657184083]
# Society and social sciences ->- Social studies ->- Psychology : [0.002850235398905713, 0.002748511223087494, 0.002886002886002886]
# Society and social sciences ->- Social studies ->- Society : [0.0028756839292530855, 0.002977553825011452, 0.002886002886002886]
# Society and social sciences ->- Social studies ->- Sociology : [0.0012469779870212495, 0.0011452130096197893, 0.0012368583797155227]
# Technology ->- Technology ->- Agriculture : [0.004886117826695509, 0.004809894640403115, 0.004947433518862091]
# Technology ->- Technology ->- Astronomical technology : [0.001501463290494974, 0.001374255611543747, 0.001443001443001443]
# Technology ->- Technology ->- Biotechnology : [0.0009924926835475252, 0.0009161704076958314, 0.0010307153164296021]
# Technology ->- Technology ->- Computing and information technology : [0.015269118208423464, 0.015345854328905176, 0.015254586683158112]
# Technology ->- Technology ->- Electronics : [0.0024176103830003816, 0.0022904260192395786, 0.0024737167594310453]
# Technology ->- Technology ->- Energy : [0.0035373457182847692, 0.0036646816307833257, 0.0035044320758606472]
# Technology ->- Technology ->- General : [0.0018322941850108156, 0.0018323408153916628, 0.0018552875695732839]
# Technology ->- Technology ->- Industry : [0.0041481104466217075, 0.004122766834631242, 0.0041228612657184084]
# Technology ->- Technology ->- Infrastructure : [0.004835220766000763, 0.004809894640403115, 0.00474129045557617]
# Technology ->- Technology ->- Machinery and tools : [0.005598676676421937, 0.005497022446174988, 0.0055658627087198514]
# Technology ->- Technology ->- Medical technology : [0.00035627942486321414, 0.00022904260192395785, 0.00041228612657184083]
# Technology ->- Technology ->- Military technology : [0.00626033846545362, 0.006184150251946862, 0.006184291898577613]
# Technology ->- Technology ->- Navigation and timekeeping : [0.0014505662298002291, 0.001374255611543747, 0.001443001443001443]
# Technology ->- Technology ->- Optical technology : [0.0011706323959791323, 0.0011452130096197893, 0.0012368583797155227]
# Technology ->- Technology ->- Space : [0.0013996691691054843, 0.001374255611543747, 0.001443001443001443]
# Technology ->- Technology ->- Transportation : [0.00928871357679094, 0.009390746678882272, 0.00927643784786642]

# %%
# Save the sets
file_prefix = 'wikivitals-lvl5-04-2022-dense' # dense because the split is 81%/9%/10% as in my article 'Fair evaluation of GMNN'
with open('wikivitals-lvl5-04-2022.json', 'r', encoding='utf8') as f:
    train_file = open(f'{file_prefix}_train.json', 'w', encoding='utf8')
    val_file = open(f'{file_prefix}_val.json', 'w', encoding='utf8')
    test_file = open(f'{file_prefix}_test.json', 'w', encoding='utf8')

    for line in f:
        observation = json.loads(line)
        if observation['id'] in ids_test:
            test_file.write(json.dumps(observation) + '\n')
        elif observation['id'] in ids_val:
            val_file.write(json.dumps(observation) + '\n')
        else:
            train_file.write(json.dumps(observation)+ '\n') # train set is the biggest, so we avoid the search in the list

    train_file.close()
    val_file.close()
    test_file.close()

# %%
# let's select 20 observations for each level 1 labels in the train set previously extracted (32 * 20 = 640 observations)
from random import sample

ids_train_sparse = []

label2ids_train = {l:[] for l in all_labels1}
for i in range(len(labels1_train)):
    label2ids_train[labels1_train[i]].append(ids_train[i])
for l in all_labels1:
    sampled_observations = sample(label2ids_train[l], 20)
    ids_train_sparse = ids_train_sparse + sampled_observations


# Save the new split
file_prefix = 'wikivitals-lvl5-04-2022-sparse' # sparse because it contains 640 observations only (among the 48512 observations in the corpus)

with open('wikivitals-lvl5-04-2022-dense_train.json', 'r', encoding='utf8') as f:
    sparse_train_file = open(f'{file_prefix}_train.json', 'w', encoding='utf8')
    for line in f:
        observation = json.loads(line)
        if observation['id'] in ids_train_sparse:
            sparse_train_file.write(json.dumps(observation) + '\n')
    sparse_train_file.close()
